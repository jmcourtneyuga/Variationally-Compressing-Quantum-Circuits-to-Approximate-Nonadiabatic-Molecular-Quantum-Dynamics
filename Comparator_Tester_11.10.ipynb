# %%
import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import Aer  
from qiskit.circuit.library.standard_gates import CXGate
from qiskit.circuit.library import XGate, CCXGate
from qiskit.quantum_info import Statevector
from ComparisonMaker import get_less_than_operations, get_less_than_logic_explanation
from CustomOperations import AND, OR, invAND, invOR, X

# %%
def lessthanlogic0(position_register, ancilla_register, comparison_register):
    logic = []
    logic.extend(OR(position_register[1], position_register[2], ancilla_register[1]))
    logic.extend(OR(position_register[3], ancilla_register[1], ancilla_register[2]))
    logic.extend(AND(position_register[4], ancilla_register[2], ancilla_register[3]))
    logic.extend(invOR(position_register[3], ancilla_register[1], ancilla_register[2]))
    logic.extend(invOR(position_register[1], position_register[2], ancilla_register[1]))

    logic.extend(AND(position_register[5], position_register[6], ancilla_register[1]))
    logic.extend(AND(ancilla_register[1], ancilla_register[3], ancilla_register[2]))
    logic.extend(OR(position_register[7], ancilla_register[2], comparison_register[0]))
    logic.extend(invAND(ancilla_register[1], ancilla_register[3], ancilla_register[2]))
    logic.extend(invAND(position_register[5], position_register[6], ancilla_register[1]))

    logic.extend(OR(position_register[1], position_register[2], ancilla_register[1]))
    logic.extend(OR(position_register[3], ancilla_register[1], ancilla_register[2]))
    logic.extend(invAND(position_register[4], ancilla_register[2], ancilla_register[3]))
    logic.extend(invOR(position_register[3], ancilla_register[1], ancilla_register[2]))
    logic.extend(invOR(position_register[1], position_register[2], ancilla_register[1]))
    return logic

def lessthanlogic1(position_register, ancilla_register, comparison_register):
    logic = []
    logic.extend(OR(position_register[0], position_register[1], ancilla_register[1]))
    logic.extend(OR(position_register[2], ancilla_register[1], ancilla_register[2]))
    logic.extend(OR(position_register[3], ancilla_register[2], ancilla_register[3]))
    logic.extend(invOR(position_register[2], ancilla_register[1], ancilla_register[2]))
    logic.extend(invOR(position_register[0], position_register[1], ancilla_register[1]))
    
    logic.extend(AND(position_register[4], position_register[5], ancilla_register[1]))
    logic.extend(AND(ancilla_register[1], ancilla_register[3], ancilla_register[2]))
    logic.extend(invAND(position_register[4], position_register[5], ancilla_register[1]))

    logic.extend(AND(position_register[6], ancilla_register[2], ancilla_register[1]))
    logic.extend(OR(position_register[7], ancilla_register[1], comparison_register[1]))
    return logic

# %%
QUBITS_NUM = 8
ANCILLARY_QUBITS_NUM = 4
COMPARATOR_QUBITS_NUM = 2
numbers = [68, 96]


x_0 = 1.5
p_0 = 1.0
δ = 1/3
N = 2**QUBITS_NUM
total_qubits = QUBITS_NUM + ANCILLARY_QUBITS_NUM + COMPARATOR_QUBITS_NUM
d = 10
Δ_x = (2*d) / N

# %%
def logics(position_register, ancilla_register, comparison_register):
    logic0 = lessthanlogic0(position_register, ancilla_register, comparison_register)
    logic1 = lessthanlogic1(position_register, ancilla_register, comparison_register)
    all_bps = {numbers[0]: logic0, numbers[1]: logic1} 
    return all_bps

def create_breakpoint_operations(number, logics, position_register, ancilla_register, comparison_register):
    return logics.get(number, [])

def create_combined_operations(numbers, n_bits, logics, position_register, ancilla_register, comparison_register):
    all_operations = []
    explanations = {}

    first_number = numbers[0]
    result1 = get_less_than_operations(first_number, n_bits)
    explanations[first_number] = result1["explanation"]

    x_gate_operations1 = []
    for bit_pos in result1["x_gate_positions"]:
        x_gate_operations1.append((XGate(), [position_register[bit_pos]]))
    
    bp_operations1 = create_breakpoint_operations(first_number, logics, position_register, ancilla_register, comparison_register)
    
    all_operations.extend(x_gate_operations1)
    all_operations.extend(bp_operations1)

    for bit_pos in result1["x_gate_positions"]:
        all_operations.append((XGate(), [position_register[bit_pos]]))

    second_number = numbers[1]
    result2 = get_less_than_operations(second_number, n_bits)
    explanations[second_number] = result2["explanation"]
    
    x_gate_operations2 = []
    for bit_pos in result2["x_gate_positions"]:
        x_gate_operations2.append((XGate(), [position_register[bit_pos]]))
    
    # Logic operations for second number
    bp_operations2 = create_breakpoint_operations(second_number, logics, position_register, ancilla_register, comparison_register)
    
    all_operations.extend(x_gate_operations2)
    all_operations.extend(bp_operations2)
    
    return all_operations, explanations

def check_all_breakpoints(main_circuit, operations):
    for gate, qubits in operations:
        main_circuit.append(gate, qubits)

def uncheck_all_breakpoints(main_circuit, operations):
    for gate, qubits in reversed(operations):
        main_circuit.append(gate, qubits)

def apply_x_gates(main_circuit, bit_positions, position_register):
    for bit_pos in bit_positions:
        main_circuit.append(XGate(), [position_register[bit_pos]])

def apply_comparison_logic(main_circuit, number, logic):
    bp_operations = logic.get(number, [])
    for gate, qubits in bp_operations:
        main_circuit.append(gate, qubits)

def handle_comparison(main_circuit, number, position_register, logic, undo_x_gates=False):
    result = get_less_than_operations(number, QUBITS_NUM)
    x_positions = result["x_gate_positions"]
    apply_x_gates(main_circuit, x_positions, position_register)
    apply_comparison_logic(main_circuit, number, logic)
    if undo_x_gates:
        apply_x_gates(main_circuit, x_positions, position_register)
    
    return result["explanation"], x_positions

def comparator_circuit(numbers, logic, position_register, ancilla_register, comparison_register, main_circuit):
    operations, explanations = create_combined_operations(
        numbers, QUBITS_NUM, logic, position_register, ancilla_register, comparison_register
    )
    check_all_breakpoints(main_circuit, operations)
    
    return explanations

# %%
def initialize_gaussian_wavepacket(x_0, p_0, δ):
    psi = np.zeros(N, dtype=complex)
    norm_factor = (1/(2*np.pi*δ**2))**(1/4)

    for position in range(N):
        x = -d + position * Δ_x

        gaussian = np.exp(-(x - x_0)**2 / (4*δ**2))
        phase = np.exp(1j * p_0 * (x - x_0))
        
        psi[position] = gaussian * phase

    psi = norm_factor * psi
    norm = np.sqrt(np.sum(np.abs(psi)**2))  
    psi = psi / norm
    
    return psi

# %%
# Simulate all possible 8-bit inputs (0 to 255)
def simulate_quantum_superposition():
    backend = Aer.get_backend('qasm_simulator')
    position_register = QuantumRegister(QUBITS_NUM, name="position")  # 
    ancilla_register = QuantumRegister(ANCILLARY_QUBITS_NUM, name="ancilla")
    comparison_register = QuantumRegister(COMPARATOR_QUBITS_NUM, name="comparison") 
    
    initial_state = initialize_gaussian_wavepacket(x_0=x_0, p_0=p_0, δ=δ)
    psi = np.zeros(2**total_qubits, dtype=complex)
    psi[:2**QUBITS_NUM] = initial_state
    
    main_circuit = QuantumCircuit(position_register, ancilla_register, comparison_register)
    all_qubits = list(position_register) + list(ancilla_register) + list(comparison_register)
    main_circuit.initialize(psi, all_qubits)
    
    # Inside simulate_quantum_superposition:
    breakpoint_logic = logics(position_register, ancilla_register, comparison_register)
    explanations = comparator_circuit(numbers, breakpoint_logic, position_register, ancilla_register, comparison_register, main_circuit)

    print("LOGIC EXPLANATIONS:")
    for number, explanation in explanations.items():
        print(f"For breakpoint {number}:")
        print(explanation)
        print()
        
    simulator = Aer.get_backend('statevector_simulator')
    result = simulator.run(main_circuit).result()
    compstate = Statevector(result.get_statevector()).data
    islessthan = Statevector(compstate).probabilities([QUBITS_NUM+ANCILLARY_QUBITS_NUM])
    islessthan_1 = Statevector(compstate).probabilities([QUBITS_NUM+ANCILLARY_QUBITS_NUM+1])
    print(f"Comparison[0] probabilities for WAVEFXN - |0⟩: {islessthan[0]:.6f}, |1⟩: {islessthan[1]:.6f}")
    print(f"Comparison[1] probabilities for WAVEFXN - |0⟩: {islessthan_1[0]:.6f}, |1⟩: {islessthan_1[1]:.6f}")
    
    for x in range(2**QUBITS_NUM):  # Loop over all 8-bit numbers
        test_circuit = QuantumCircuit(position_register, ancilla_register, comparison_register)
        
        # Encode x as a quantum state using a delta function (bit-flip where needed)
        for i in range(QUBITS_NUM):
            if (x >> i) & 1:  # If bit i of x is 1, apply X-gate
                test_circuit.x(position_register[i])
        
        # Apply the quantum comparison circuit
        comparator_circuit(numbers, breakpoint_logic, position_register, ancilla_register, comparison_register, test_circuit)
        
        simulator = Aer.get_backend('statevector_simulator')
        result = simulator.run(test_circuit).result()
        compstate = Statevector(result.get_statevector()).data
        islessthan = Statevector(compstate).probabilities([QUBITS_NUM+ANCILLARY_QUBITS_NUM])
        islessthan_1 = Statevector(compstate).probabilities([QUBITS_NUM+ANCILLARY_QUBITS_NUM+1])
        print(f"Comparison[0] probabilities for input {x}- |0⟩: {islessthan[0]:.6f}, |1⟩: {islessthan[1]:.6f}")
        print(f"Comparison[1] probabilities for input {x}- |0⟩: {islessthan_1[0]:.6f}, |1⟩: {islessthan_1[1]:.6f}")

# Run the simulation
simulate_quantum_superposition()
# Out:
# LOGIC EXPLANATIONS:
# For breakpoint 68:
# Number: 68 (binary: 01000100)
# ------------------------------------------------------------
# For a 8-bit string to be LESS THAN 68:
# b_7 = 0 AND b_6 = 0 OR (b_5 = 0 AND b_4 = 0 AND b_3 = 0 AND b_2 = 0)
#
#
# For breakpoint 96:
# Number: 96 (binary: 01100000)
# ------------------------------------------------------------
# For a 8-bit string to be LESS THAN 96:
# b_7 = 0 AND b_6 = 0 OR (b_5 = 0)
#
#
# Comparison[0] probabilities for WAVEFXN - |0⟩: 0.862672, |1⟩: 0.137328
# Comparison[1] probabilities for WAVEFXN - |0⟩: 0.264881, |1⟩: 0.735119
# Comparison[0] probabilities for input 0- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 0- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 1- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 1- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 2- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 2- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 3- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 3- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 4- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 4- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 5- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 5- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 6- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 6- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 7- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 7- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 8- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 8- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 9- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 9- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 10- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 10- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 11- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 11- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 12- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 12- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 13- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 13- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 14- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 14- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 15- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 15- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 16- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 16- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 17- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 17- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 18- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 18- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 19- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 19- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 20- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 20- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 21- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 21- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 22- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 22- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 23- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 23- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 24- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 24- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 25- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 25- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 26- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 26- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 27- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 27- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 28- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 28- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 29- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 29- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 30- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 30- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 31- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 31- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 32- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 32- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 33- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 33- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 34- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 34- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 35- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 35- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 36- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 36- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 37- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 37- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 38- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 38- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 39- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 39- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 40- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 40- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 41- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 41- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 42- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 42- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 43- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 43- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 44- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 44- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 45- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 45- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 46- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 46- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 47- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 47- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 48- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 48- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 49- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 49- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 50- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 50- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 51- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 51- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 52- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 52- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 53- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 53- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 54- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 54- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 55- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 55- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 56- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 56- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 57- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 57- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 58- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 58- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 59- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 59- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 60- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 60- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 61- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 61- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 62- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 62- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 63- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 63- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 64- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 64- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 65- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 65- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 66- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 66- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 67- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 67- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 68- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 68- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 69- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 69- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 70- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 70- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 71- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 71- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 72- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 72- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 73- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 73- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 74- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 74- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 75- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 75- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 76- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 76- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 77- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 77- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 78- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 78- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 79- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 79- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 80- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 80- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 81- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 81- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 82- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 82- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 83- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 83- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 84- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 84- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 85- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 85- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 86- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 86- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 87- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 87- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 88- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 88- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 89- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 89- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 90- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 90- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 91- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 91- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 92- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 92- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 93- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 93- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 94- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 94- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 95- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 95- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 96- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 96- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 97- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 97- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 98- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 98- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 99- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 99- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 100- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 100- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 101- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 101- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 102- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 102- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 103- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 103- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 104- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 104- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 105- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 105- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 106- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 106- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 107- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 107- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 108- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 108- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 109- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 109- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 110- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 110- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 111- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 111- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 112- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 112- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 113- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 113- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 114- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 114- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 115- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 115- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 116- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 116- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 117- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 117- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 118- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 118- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 119- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 119- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 120- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 120- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 121- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 121- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 122- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 122- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 123- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 123- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 124- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 124- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 125- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 125- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 126- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 126- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 127- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 127- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 128- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 128- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 129- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 129- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 130- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 130- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 131- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 131- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 132- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 132- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 133- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 133- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 134- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 134- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 135- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 135- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 136- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 136- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 137- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 137- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 138- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 138- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 139- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 139- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 140- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 140- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 141- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 141- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 142- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 142- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 143- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[1] probabilities for input 143- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 144- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 144- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 145- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 145- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 146- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 146- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 147- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 147- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 148- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 148- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 149- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 149- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 150- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 150- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 151- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 151- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 152- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 152- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 153- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 153- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 154- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 154- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 155- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 155- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 156- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 156- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 157- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 157- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 158- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 158- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 159- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 159- |0⟩: 0.000000, |1⟩: 1.000000
# Comparison[0] probabilities for input 160- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 160- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 161- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 161- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 162- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 162- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 163- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 163- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 164- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 164- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 165- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 165- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 166- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 166- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 167- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 167- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 168- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 168- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 169- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 169- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 170- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 170- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 171- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 171- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 172- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 172- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 173- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 173- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 174- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 174- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 175- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 175- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 176- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 176- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 177- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 177- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 178- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 178- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 179- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 179- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 180- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 180- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 181- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 181- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 182- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 182- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 183- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 183- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 184- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 184- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 185- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 185- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 186- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 186- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 187- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 187- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 188- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 188- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 189- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 189- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 190- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 190- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 191- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 191- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 192- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 192- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 193- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 193- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 194- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 194- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 195- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 195- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 196- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 196- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 197- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 197- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 198- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 198- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 199- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 199- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 200- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 200- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 201- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 201- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 202- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 202- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 203- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 203- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 204- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 204- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 205- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 205- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 206- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 206- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 207- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 207- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 208- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 208- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 209- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 209- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 210- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 210- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 211- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 211- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 212- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 212- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 213- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 213- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 214- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 214- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 215- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 215- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 216- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 216- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 217- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 217- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 218- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 218- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 219- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 219- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 220- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 220- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 221- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 221- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 222- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 222- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 223- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 223- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 224- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 224- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 225- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 225- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 226- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 226- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 227- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 227- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 228- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 228- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 229- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 229- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 230- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 230- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 231- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 231- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 232- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 232- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 233- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 233- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 234- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 234- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 235- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 235- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 236- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 236- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 237- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 237- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 238- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 238- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 239- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 239- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 240- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 240- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 241- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 241- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 242- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 242- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 243- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 243- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 244- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 244- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 245- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 245- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 246- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 246- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 247- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 247- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 248- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 248- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 249- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 249- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 250- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 250- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 251- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 251- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 252- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 252- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 253- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 253- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 254- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 254- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[0] probabilities for input 255- |0⟩: 1.000000, |1⟩: 0.000000
# Comparison[1] probabilities for input 255- |0⟩: 1.000000, |1⟩: 0.000000
